# %% [markdown]
# # (just a practice module and for referencing purpose)

# %% [markdown]
# We will install Gensim library

# %%
# !pip install gensim

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %% [markdown]
# Will use google news data (100 billion words trained), vector dimension is 300 a

# %%
import gensim.downloader as api

# %% [markdown]
# following line may take some time based on your internet speed

# %%
vectors = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
sample_word = vectors['Dance']

# %%
sample_word # u can make out an array of 300 dim below
# Out:
# array([ 0.09375   , -0.23828125,  0.18359375, -0.03540039,  0.08447266,
#         0.06396484, -0.25585938, -0.3046875 , -0.25390625,  0.0189209 ,
#        -0.13378906, -0.02929688,  0.07763672,  0.16601562, -0.01989746,
#         0.34375   ,  0.07177734, -0.32617188,  0.04614258, -0.01123047,
#         0.2890625 ,  0.08496094,  0.125     , -0.08496094, -0.12792969,
#         0.21777344,  0.03881836,  0.07177734,  0.04980469, -0.2734375 ,
#        -0.15039062,  0.08544922, -0.22558594, -0.05712891, -0.07568359,
#        -0.37890625, -0.08349609,  0.06445312, -0.15234375,  0.10546875,
#        -0.29101562, -0.14648438,  0.10888672, -0.11035156,  0.11230469,
#        -0.10400391, -0.21289062, -0.13476562,  0.32226562,  0.35351562,
#         0.06396484, -0.02502441,  0.13769531,  0.05029297,  0.35546875,
#        -0.07519531,  0.22949219, -0.13085938, -0.39453125, -0.15039062,
#         0.22167969,  0.21582031, -0.13671875, -0.01757812, -0.09667969,
# ...

# %%
sample_word = vectors['Music']

# %%
sample_word
# Out:
# array([ 0.07568359, -0.25976562, -0.26953125, -0.20214844,  0.07421875,
#         0.04785156,  0.10253906, -0.22167969,  0.00068665, -0.05126953,
#        -0.03808594, -0.06640625, -0.00994873, -0.0456543 ,  0.21972656,
#        -0.10253906,  0.05786133,  0.19628906, -0.16894531, -0.20605469,
#         0.17382812,  0.25195312,  0.00418091, -0.02819824, -0.04956055,
#        -0.01422119,  0.18457031, -0.10986328,  0.11865234,  0.03051758,
#        -0.0480957 , -0.00592041, -0.42382812,  0.06884766,  0.05834961,
#        -0.41992188,  0.15625   , -0.02697754, -0.25195312,  0.00878906,
#        -0.4140625 , -0.0402832 , -0.16015625, -0.01269531,  0.13671875,
#        -0.01257324, -0.02307129,  0.18554688,  0.03442383,  0.24511719,
#        -0.16015625,  0.01104736,  0.16796875,  0.26757812,  0.3359375 ,
#         0.20605469, -0.17578125,  0.0378418 , -0.17675781, -0.37890625,
#        -0.00537109,  0.12109375, -0.05786133,  0.01733398, -0.03955078,
# ...

# %%
#lets check some similarities

# %%
vectors.most_similar('Music')
# Out:
# [('music', 0.6595720648765564),
#  ('Classical_Music', 0.6025565266609192),
#  ('Orchestra', 0.5901161432266235),
#  ('Choral', 0.5899642705917358),
#  ('Choral_Music', 0.5818769931793213),
#  ('Concerts', 0.5749800205230713),
#  ('Folk_Music', 0.5689655542373657),
#  ('Singer_Songwriters', 0.5680757761001587),
#  ('Vocal_Jazz', 0.564782440662384),
#  ('Jazz_Composers_Orchestra', 0.5643922686576843)]

# %%
vectors.similarity('Dance','Music')
# Out:
# 0.55395985
